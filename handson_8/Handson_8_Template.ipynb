# %% [markdown]
# # Strings
#
# To submit this assignment in D2l, post the link to your notebook file on your GitHub account.

# %% [markdown]
# ## 10.1 Email Creator
# Create a program that reads a file and creates a series of emails.
#
# ### Console:
# ```powershell
# Email Creator
#
# ================================================================
# To: jbutler@gmail.com
# From: noreply@deals.com
# Subject: Deals!
#
# Hi James,
#
# We've got some great deals for you. Check our website!
# ================================================================
# To:	josephine_darakjy@darakjy.org
# From:	noreply@deals.com
# Subject: Deals!
#
# Hi Josephine,
#
# We've got some great deals for you. Check our website!
# ================================================================
# To:	art@venere.org
# From:	noreply@deals.com
# Subject: Deals!
#
# Hi Art,
#
# We've got some great deals for you. Check our website!
# ```
#
# ### Specifications:
# - Use `email.csv` file:
# - Use `email_template.txt` file:
# - When the program starts, it should read the email addresses and first names from the file, merge them into the mass email template, and display the results on the console.
# - All email addresses should be converted to **lowercase**.
# - All first names should be converted to **title case**.
# - If you add names to the list of email addresses, the program should create more emails.
# - If you modify the template, the program should change the content of the email that’s created.

# %%
import csv

def email_import():
    email_list=[]
    with open("email.csv","r") as file:
        reader=csv.reader(file)
        for row in reader:
            email_list.append(row)
    return email_list

def template_import():
    template=[]
    with open("email_template.txt","r") as file:
        for line in file:
            template.append(line)
    return template

def email_assembler(fname,email,template):
    working_template=template
    for item in working_template:
        item=item.rstrip()
        if item.find("{email}") != -1:
            item=item.replace("{email}",email)
        if item.find("{first_name}") != -1:
            item=item.replace("{first_name}",fname.title())
        print(item)
    
def main():
    email_list=email_import()
    template=template_import()
    index=0
    print("Email Creator\n")
    for item in email_list:
        print("===============================================")
        fname=email_list[index][0]
        email=email_list[index][2]
        email_assembler(fname,email,template)
        index+=1
    
if __name__=="__main__":
    main()
# Out:
# Email Creator
#
# ===============================================
# To:      jbutt@gmail.com
# From:    noreply@deals.com
# Subject: Deals!
#
# Hi James,
#
# We've got some great deals for you. Check our website!
# ===============================================
# To:      josephine_darakjy@darakjy.org
# From:    noreply@deals.com
# Subject: Deals!
#
# Hi Josephine,
#
# We've got some great deals for you. Check our website!
# ===============================================
# To:      art@venere.org
# From:    noreply@deals.com
# Subject: Deals!
#
# Hi Art,
#
# We've got some great deals for you. Check our website!

# %% [markdown]
# ## 10.2 Pig Latin Translator
#
# Create a program that translates English to Pig Latin.
#
# ### Console:
# ```powershell
# Pig Latin Translator
#
# Enter text: Tis but a scratch.
# English:	tis but a scratch
# Pig Latin:	istay utbay away atchscray
#
# Continue? (y/n): y
#
# Enter text: We are the knights who say nee!
# English:	we are the knights who say nee
# Pig Latin:	eway areway ethay ightsknay owhay aysay eenay
#
# Continue? (y/n): n
#
# Bye!
# ```
#
# ### Specifications:
# - Convert the English to lowercase before translating.
# - Remove the following punctuation characters before translating `! , ; : - . ?`
# - Assume that words are separated from each other by a single space.
# - If the word starts with a vowel, just add *way* to the end of the word.
# - If the word starts with a consonant, move all of the consonants that appear before the first vowel to the end of the word, then add *ay* to the end of the word.
#
# ### Note:
# - There are no official rules for Pig Latin. Most people agree on how words that begin with consonants are translated, but there are many different ways to handle words that begin with vowels.

# %%
def translate(entry):
    banned_characters=["!",",",";",":","-",".","?","'"]
    vowels=["a","e","i","o","u"]
    entry=entry.lower()
    cleaned=""
    translated_list=[]
    response=""
    for character in entry:
        if character in banned_characters:
            continue
        else:
            cleaned+=character
    clean_list=cleaned.split(" ")
    for item in clean_list:
        response+=item
        response+=" "
    print("English:\t"+response)
    response=""
    for item in clean_list:
        found=[]
        if item[:1] in vowels:
            item+="way"
            translated_list.append(item)
        else:
            for character in item:
                for vowel in vowels:
                    if item.find(vowel) != -1:
                        found.append(item.find(vowel))
                if found!=[]:
                    break
            found_item=min(found)
            thing1=item[:found_item]
            thing2=item[found_item:]
            thing3=thing2+thing1+"ay"
            translated_list.append(thing3)
    for item in translated_list:
        response+=item
        response+=" "
    print("Pig Latin:\t"+response)
    return
    
    
def main():
    print("Pig Latin Translator\n")
    cont="y"
    while cont.lower()=="y":
        entry=input("\nEnter text:\t")
        translate(entry)
        cont=input("Continue? (y/n):")
    print("\nBye!")

if __name__=="__main__":
    main()
# Out:
# Pig Latin Translator
#
#
# Enter text:	Hello, let's see if this thing works.
# English:	hello lets see if this thing works
# Pig Latin:	ellohay etslay eesay ifway isthay ingthay orksway
